# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Test-de-l'environement" data-toc-modified-id="Test-de-l'environement-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Test de l'environement</a></span></li><li><span><a href="#Regression-Lineaire" data-toc-modified-id="Regression-Lineaire-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Regression Lineaire</a></span><ul class="toc-item"><li><span><a href="#Regression-Lineaire-a-partir-d'une-droite" data-toc-modified-id="Regression-Lineaire-a-partir-d'une-droite-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Regression Lineaire a partir d'une droite</a></span></li><li><span><a href="#Regression-Lineaire-a-partir-d'un-dataset-de-5-points" data-toc-modified-id="Regression-Lineaire-a-partir-d'un-dataset-de-5-points-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Regression Lineaire a partir d'un dataset de 5 points</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Test de l'environement

# %%
# %run test_ML_Jupyter_Env.ipy
# Out:
# => nvidia-smi :
#
# Wed Jun 27 14:37:04 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 390.48                 Driver Version: 390.48                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX TIT...  Off  | 00000000:01:00.0 Off |                  N/A |
# |  0%   56C    P0    58W / 250W |      0MiB / 12210MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
import pandas
pandas.DataFrame.plot?

# %% [markdown]
# # Regression Lineaire

# %% [markdown]
# ## Regression Lineaire a partir d'une droite

# %%
# %run simpleLinearRegression.py -h

# %%
# %reset -f -s

# %%
# %matplotlib notebook

# %%
# %run simpleLinearRegression.py -e 20 -n 1000
# Out:
# => Doing Pandas dataframe normalization ...
# => DONE.
#
# => myArgs.nbSamples = 1000 	myArgs.batch_size = 50 	myArgs.epochs = 20 and myArgs.validation_split = 20 %
# => matplotlib backend = <module://ipykernel.pylab.backend_inline>
# => kernel_initializer = glorot_uniform
#
# => myArgs.nbSamples = 1000 	myArgs.batch_size = 50 	myArgs.epochs = 20 and myArgs.validation_split = 20 %
#
# => Loss function = <mse> myArgs.optimizer = <sgd>
#
# => THE DATA WAS NORMALIZED, hence slope=-0.94	y_Intercept=0.03
#
# => DISPLAYING MODEL IN SVG :
# <img src="data:image/png;base64,..." width="959.7499713972219">

# %%
# %reset -f -s
# %run simpleLinearRegression.py -P -e 20 -n 1000

# %%
# %reset -f -s
# %run simpleLinearRegression.py -E 0 -e 100

# %%
# %matplotlib inline

# %%
# %reset -f -s
# %run simpleLinearRegression.py -P -e 20 -E 0 -l mse

# %%
# %reset -f -s
# %run simpleLinearRegression.py -l mse -o rmsprop -e 25 -E 0 -S -P

# %%
# %reset -f -s
# %run simpleLinearRegression.py -l rmse -S -e 100 -P -O adam

# %%
# %reset -f -s
# %run simpleLinearRegression.py -l rmse -S -e 100 -P -O adam -E 0

# %%
# %reset -f -s
# %matplotlib inline
# %run simpleLinearRegression.py -l rmse -S -e 11
isnotebook()

# %%
from IPython.display import Image, SVG, display
modelFileName = 'model.png'
import os
if os.path.exists(modelFileName) : display( Image(filename=modelFileName) )

# %%
from IPython.display import Image, SVG, display
modelFileName = 'model.svg'
if os.path.exists(modelFileName) : display( SVG(filename=modelFileName) )

# %%
# %whos int float ndarray str DataFrame Namespace

# %%
arguments

# %%
pda.options.display.max_rows = 20

# %%
df

# %%
df.info()

# %%
df.describe()

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4])

# %%
import matplotlib as mpl
mpl.get_backend()

# %% [markdown]
# ## Regression Lineaire a partir d'un dataset de 5 points

# %%
# %reset -f -s
# %matplotlib inline

# %%
# %run ./testLinearRegression.py ../../data/OutputPower.txt -e 500 -E 0 -l mse

# %%
# %run ./simpleLinearRegression.py -l mse -S -e 100 -P -O sgd -E 0 ../../data/OutputPower.txt

# %%
pda.Series( history.history['loss'] )

# %%
arguments

# %%
# %whos int float ndarray str DataFrame Namespace

# %%
df

# %%
df.describe()

# %%
# %run ./simpleLinearRegression.py ../../data/OutputPower.txt -e 450 -E 0

# %%
import datetime,dateutil;datetime.datetime.now( tz=dateutil.tz.tzlocal() ).strftime('%d/%m/%Y %H:%M:%S %Z %z')
