# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 8000)
a = 2
b = 0
y1 = a * x + b
plt.plot(x,y1, label = "Une droite")
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
from IPython.display import Math
Math('y = ax+b')
# Out:
# $$y = ax+b$$

# %% [markdown]
# Soit une droite y(x) telle que :

# %%
y2=x**2/1000
plt.plot(x,y2,label = "Une parabole")
plt.legend()
