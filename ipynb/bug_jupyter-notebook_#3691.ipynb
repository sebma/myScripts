# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# [Bug : Need to run plt.plot() twice from a freshly started notebook to see the plot](https://github.com/jupyter/notebook/issues/3691)

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
# Out:
# <img src="data:image/png;base64,..." width="639.8333142648146">

# %%
plt.plot([1,2,3,4])
